# %% [markdown]
# # LangChain Loader 示例 Notebook
#
# 这是一个用于测试 **.ipynb 文档加载** 的示例文件。

# %%
print('Hello LangChain Loader')
# Out:
# Hello LangChain Loader

# %% [markdown]
# ## 小结
# Notebook 本质是 JSON 结构，
# 适合用 Unstructured 或 JSON Loader 解析。
